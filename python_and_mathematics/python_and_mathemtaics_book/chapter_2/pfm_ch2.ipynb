# %%
3 / 5
# Out:
# 0.6

# %%
2 + 2
# Out:
# 4

# %%
3 - 1
# Out:
# 2

# %%
3 * 5
# Out:
# 15

# %%
20 / 5
# Out:
# 4.0

# %%
2**4
# Out:
# 16

# %%
5 % 2
# Out:
# 1

# %%
(2**3 + 1) / 4
# Out:
# 2.25

# %% [markdown]
# $a + b$

# %% [markdown]
# $-a$

# %% [markdown]
# $ab$

# %% [markdown]
# $a \cdot b$

# %% [markdown]
# $a \times b$

# %% [markdown]
# $a/b$

# %% [markdown]
# $\frac{a}{b}$

# %% [markdown]
# $a^b$

# %% [markdown]
# Matrix:
# <expression>
#     \begin{pmatrix}
#     a&b\\
#     c&d\\
#     e&f\\
#     \end{pmatrix}

# %% [markdown]
# Intergrals:
#     $$
#     \int_{0}^{\infty} x dx
#     $$

# %% [markdown]
# Summations:
# $$
# \sum_{0}^{n} i
# $$
