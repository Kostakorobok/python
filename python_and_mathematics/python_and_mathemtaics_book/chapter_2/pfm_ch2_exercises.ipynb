# %%
3 + 8
# Out:
# 11

# %%
3 / 7
# Out:
# 0.42857142857142855

# %%
456 / 21
# Out:
# 21.714285714285715

# %%
(4**3 + 2)/(2 * 5) - 5**(1/2)
# Out:
# 4.36393202250021

# %% [markdown]
# # Euler's equation
#
# $$
# e^{i/pi} = -1
# $$
# or
# $$
# \Large e^{\frac{i}{\pi}} = -1
# $$

# %% [markdown]
# $\large \text{(a)} \; \frac{4^3 + 2}{2 \times 5}$

# %% [markdown]
# $\large \text{(b)} \; -5^{\frac{1}{2}}$

# %% [markdown]
# $\large{\text{(c)}\;} \huge{\frac{df}{dx}}$

# %% [markdown]
# $\large \text{(d)} \int_{5}^{12} \; x^2 \cdot dx$

# %% [markdown]
# $\large \text{(e)}$ <expression>
#     \begin{pmatrix}
#     4&12&3 \\
#     2&x&i
#     \end{pmatrix}
