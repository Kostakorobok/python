# %%
import sympy

# %%
x = sympy.Symbol("x")
quadratic = 8 * x**2 - 59 * x + 21
sympy.solveset(quadratic, x)
# Out:
# {3/8, 7}

# %%
x = sympy.Symbol("x")
quadratic = x**2 + 10 * x + 25
sympy.solveset(quadratic, x)
# Out:
# {-5}

# %%
m = sympy.Symbol("m")
quadratic = m**2 - 2 * m - 120
sympy.solveset(quadratic, m)
# Out:
# {-10, 12}
